# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import random

# %matplotlib inline

# %% [markdown]
# # Preprocessing of  Data

# %%
train_path = 'dataset/Training'
test_path = 'dataset/Testing'

# %%
X_train = []
y_train = []
img_size = (300,300)

# %%
for folder in os.listdir(train_path):
    print(f"In folder: {folder}")
    for file in os.listdir(os.path.join(train_path,folder)):
        img_path = os.path.join(train_path,folder,file)
        img  = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
        X_train.append(img)
        y_train.append(folder)
# Out:
# In folder: glioma_tumor
# In folder: meningioma_tumor
# In folder: no_tumor
# In folder: pituitary_tumor

# %%
for folder in os.listdir(test_path):
    print(f"In folder: {folder}")
    for file in os.listdir(os.path.join(test_path,folder)):
        img_path = os.path.join(test_path,folder,file)
        img  = cv2.imread(img_path, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
        X_train.append(img)
        y_train.append(folder)
# Out:
# In folder: glioma_tumor
# In folder: meningioma_tumor
# In folder: no_tumor
# In folder: pituitary_tumor

# %%
X_train = np.array(X_train, dtype='float32')

# %%
X_train = X_train / 255.0

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(15, 15))

random_indices = np.random.choice(len(X_train), size=10, replace=False) 
for i, idx in enumerate(random_indices):
    plt.subplot(5, 5, i + 1)
    plt.imshow(X_train[idx])
    plt.xlabel(y_train[idx])
    plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-03-31 17:44:24.878137: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-31 17:44:24.901171: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-31 17:44:26.096326: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-31 17:44:30.324203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-31 17:44:34.998511: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=False,
        vertical_flip=False,
        fill_mode='nearest')

# %%
datagen.fit(X_train)

# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# One-Hot Encoding
y_train = np.array(pd.get_dummies(y_train))

# %%
#Splitting Data into training, testing and validation
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
print(f'X_train shape: {(X_train).shape}\n'
      f'y_train shape: {(y_train).shape}\n'
      f'X_test shape: {(X_test).shape}\n'
      f'y_test shape: {(y_test).shape}\n'
      f'X_valid shape: {(X_valid).shape}\n'
      f'y_valid shape: {(y_valid).shape}')
# Out:
# X_train shape: (2643, 300, 300, 3)
# y_train shape: (2643, 4)
# X_test shape: (327, 300, 300, 3)
# y_test shape: (327, 4)
# X_valid shape: (294, 300, 300, 3)
# y_valid shape: (294, 4)

# %%
print(f"Maximum and Minimum pixel value after normalization: {X_train.max()} - {X_train.min()}")
# Out:
# Maximum and Minimum pixel value after normalization: 1.0 - 0.0

# %% [markdown]
# # Building CNN Model LENET-5

# %%
from tensorflow.keras import Sequential, activations
from tensorflow.keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, Dense, Resizing, BatchNormalization, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# %%
input_shape = X_train.shape
print(input_shape)
# Out:
# (2643, 300, 300, 3)

# %%
height, width, _ = X_train.shape[1:]
print("Width:", width)
print("Height:", height)
# Out:
# Width: 300
# Height: 300

# %%
# Create LeNet-5 model
lenet_model = Sequential([
    # Resizing layer
    Resizing(32, 32, interpolation='bilinear', input_shape=(width, height, 3)),
    
    # 1st Layer
    Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid', input_shape=(width, height, 3)),
    BatchNormalization(),
    # 2nd Layer
    AveragePooling2D(pool_size=(2, 2)),
    
    
    # 3rd Layer
    Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'),
      BatchNormalization(),
    # 4th Layer 
    AveragePooling2D(pool_size=(2, 2)),
  
    
    Flatten(),
    
    # 5th Layer
    Dense(120, activation='relu'),
    Dense(84, activation='relu'),
    Dense(4, activation='softmax')
])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
lenet_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 6)      │            24 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 14, 14, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 10, 10, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 5, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           340 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,584 (240.56 KB)
#  Trainable params: 61,540 (240.39 KB)
#  Non-trainable params: 44 (176.00 B)

# %%
# Compile the model
lenet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = lenet_model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=20,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.5404 - loss: 1.0608 - val_accuracy: 0.3946 - val_loss: 1.3436
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7588 - loss: 0.6412 - val_accuracy: 0.3537 - val_loss: 1.3132
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8526 - loss: 0.4304 - val_accuracy: 0.3469 - val_loss: 1.3890
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8679 - loss: 0.3663 - val_accuracy: 0.3571 - val_loss: 1.5184
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9124 - loss: 0.2791 - val_accuracy: 0.4184 - val_loss: 1.3456
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9413 - loss: 0.2000 - val_accuracy: 0.4660 - val_loss: 1.2777
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9652 - loss: 0.1437 - val_accuracy: 0.5272 - val_loss: 1.2424
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9735 - loss: 0.1071 - val_accuracy: 0.6224 - val_loss: 1.0465
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9815 - loss: 0.0890 - val_accuracy: 0.7075 - val_loss: 0.8290
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9851 - loss: 0.0627 - val_accuracy: 0.7789 - val_loss: 0.6571
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9957 - loss: 0.0383 - val_accuracy: 0.7959 - val_loss: 0.6287
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9941 - loss: 0.0318 - val_accuracy: 0.8435 - val_loss: 0.5231
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9975 - loss: 0.0231 - val_accuracy: 0.8673 - val_loss: 0.4254
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9992 - loss: 0.0212 - val_accuracy: 0.8810 - val_loss: 0.4678
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9988 - loss: 0.0139 - val_accuracy: 0.8878 - val_loss: 0.3997
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9987 - loss: 0.0133 - val_accuracy: 0.8844 - val_loss: 0.4118
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9998 - loss: 0.0124 - val_accuracy: 0.8776 - val_loss: 0.4431
# Epoch 18/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9973 - loss: 0.0143 - val_accuracy: 0.8946 - val_loss: 0.3472
# Epoch 19/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9960 - loss: 0.0174 - val_accuracy: 0.8912 - val_loss: 0.3912
# Epoch 20/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9960 - loss: 0.0214 - val_accuracy: 0.8673 - val_loss: 0.4967

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = lenet_model.evaluate(X_test, y_test, verbose=1)

# Print the test accuracy
print('Test Accuracy:', test_accuracy)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8460 - loss: 0.5624
# Test Accuracy: 0.8501529097557068

# %%
from sklearn.metrics import recall_score

y_test_labels = np.argmax(y_test, axis=1)

# Make predictions on the test dataset
y_pred = lenet_model.predict(X_test)

# Convert predicted probabilities to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate recall score
recall = recall_score(y_test_labels, y_pred_classes, average='weighted')

# Print the recall score
print('Recall Score:', recall)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Recall Score: 0.8501529051987767

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_labels, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82        79
#            1       0.81      0.71      0.76        90
#            2       0.93      0.88      0.90        73
#            3       0.88      0.96      0.92        85
#
#     accuracy                           0.85       327
#    macro avg       0.85      0.85      0.85       327
# weighted avg       0.85      0.85      0.85       327

# %%
class_names = []
for folder in os.listdir(train_path):
    class_names.append(folder)

class_names
# Out:
# ['no_tumor', 'pituitary_tumor', 'meningioma_tumor', 'glioma_tumor']

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # ALexNet

# %%
alexnet_model = Sequential([
            # Resizing
            Resizing(227,227, interpolation='bilinear', input_shape=(width,height,3)),
    
            #1st Convolutional Layer
            Conv2D(filters=96,kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)),
            BatchNormalization(),
            MaxPooling2D(pool_size=(3,3), strides=(2,2)),
            
            #2nd Convolutional Layer
            Conv2D(filters=256,kernel_size=(5,5), strides=(1,1), padding='same', activation='relu' ),
            BatchNormalization(),
            MaxPooling2D(pool_size=(3,3), strides=(2,2)),
             
            #3rd Convolutional Layer
            Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
            BatchNormalization(),
                
            #4th Convolutional Layer
            Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
            BatchNormalization(),        
            
            #4th Convolutional Layer
            Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'),
            BatchNormalization(),
            MaxPooling2D(pool_size=(3,3), strides=(2,2)),
                     
            Flatten(),
                     
            Dense(4096, activation='relu'),
            Dropout(0.5),
            
            Dense(4096, activation='relu'),
            Dropout(0.5),
                     
            Dense(4, activation='softmax')
])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
alexnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = lenet_model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    epochs=20,
    batch_size=64,
    verbose=1
)
# Out:
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9959 - loss: 0.0197 - val_accuracy: 0.8878 - val_loss: 0.4134
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9987 - loss: 0.0113 - val_accuracy: 0.8810 - val_loss: 0.4258
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9977 - loss: 0.0100 - val_accuracy: 0.8707 - val_loss: 0.5310
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9940 - loss: 0.0292 - val_accuracy: 0.8946 - val_loss: 0.4410
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9977 - loss: 0.0108 - val_accuracy: 0.8776 - val_loss: 0.4542
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9957 - loss: 0.0146 - val_accuracy: 0.8946 - val_loss: 0.4483
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9989 - loss: 0.0060 - val_accuracy: 0.8810 - val_loss: 0.4851
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9811 - loss: 0.0628 - val_accuracy: 0.8061 - val_loss: 0.7406
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9868 - loss: 0.0411 - val_accuracy: 0.8639 - val_loss: 0.5632
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9953 - loss: 0.0182 - val_accuracy: 0.8912 - val_loss: 0.4565
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9994 - loss: 0.0042 - val_accuracy: 0.8878 - val_loss: 0.5382
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9975 - loss: 0.0084 - val_accuracy: 0.8673 - val_loss: 0.5393
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9990 - loss: 0.0055 - val_accuracy: 0.8878 - val_loss: 0.4850
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9995 - loss: 0.0031 - val_accuracy: 0.8980 - val_loss: 0.4453
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 0.8912 - val_loss: 0.5075
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9990 - loss: 0.0029 - val_accuracy: 0.8980 - val_loss: 0.4570
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9983 - loss: 0.0040 - val_accuracy: 0.9014 - val_loss: 0.4660
# Epoch 18/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 0.9048 - val_loss: 0.4990
# Epoch 19/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9974 - loss: 0.0070 - val_accuracy: 0.8946 - val_loss: 0.4367
# Epoch 20/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.8980 - val_loss: 0.4713

# %%
test_loss, test_accuracy = lenet_model.evaluate(X_test, y_test, verbose=1)

# Print the test accuracy
print('Test Accuracy:', test_accuracy)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9032 - loss: 0.4281
# Test Accuracy: 0.9021406769752502

# %%
y_test_labels = np.argmax(y_test, axis=1)

# Make predictions on the test dataset
y_pred = lenet_model.predict(X_test)

# Convert predicted probabilities to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate recall score
recall = recall_score(y_test_labels, y_pred_classes, average='weighted')

# Print the recall score
print('Recall Score:', recall)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Recall Score: 0.9021406727828746

# %%
print(classification_report(y_test_labels, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86        79
#            1       0.89      0.81      0.85        90
#            2       0.93      0.96      0.95        73
#            3       0.93      0.99      0.96        85
#
#     accuracy                           0.90       327
#    macro avg       0.90      0.90      0.90       327
# weighted avg       0.90      0.90      0.90       327

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
